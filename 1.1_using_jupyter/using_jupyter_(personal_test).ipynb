# %% [markdown]
# # Using Jupyter(Need)

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don’t.

# %% [markdown]
# The ships *hung in the sky* in much the same way that **bricks don't.**<sup>1</sup><sub>QUOTE</sub>

# %% [markdown]
# # heading

# %% [markdown]
# `print(Hello World!)`

# %% [markdown]
# ```python
# print(Hello World!)
# ```

# %% [markdown]
# ```python
# print(Hello World!)
# ```

# %% [markdown]
# [youtube](https://youtube.com)

# %% [markdown]
# ![kms](https://pbs.twimg.com/profile_images/1815625538771505152/DIJXci_J_400x400.jpg)

# %% [markdown]
# ![](C:\Users\caden\Documents\GitHub\learning-portfolio-2024-aug-ebdb3\1.1_using_jupyter\.ipynb_checkpoints\mitsuaya charm.png)

# %% [markdown]
# |A|B|C|
# |:---|:--:|---:|
# |a|b|c|
# |a1|b1|c1|
# |test|test2|test3|

# %% [markdown]
# 1. a
# 2. b
# 3. c

# %% [markdown]
# 1. a
#     - a1
#     - a2
# 2. b
#     - b2

# %% [markdown]
# $$
# x=\dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ## Introduction
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Polynomialdeg2.svg/800px-Polynomialdeg2.svg.png)
#
# (*Image from the [Wikipedia page on Quadratic Equations](https://en.wikipedia.org/wiki/Quadratic_equation))*
#
# The general form of a quadratic equation is:
# $$
# ax^2 + bx + c = 0
# $$
#
# ## Solutions
# Provided $a \ne 0$, we can use an elementary algebraic equation called [completing the square](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution:
# $$
# x = \dfrac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# $$
#
# ## Discriminant
# The quantity $\Delta = b^2 - 4ac$ is called the **discriminant** of the equation and decides the nature of its solutions. The table below shows the various possiblities.
#
# |Discriminant|Roots|
# |:---|---:|
# |$\Delta = b^2 - 4ac = 0$|A single solution of $-b/(2a)$|
# |$\Delta = b^2 - 4ac > 0$|Two distinct solutions|
# |$\Delta = b^2 - 4ac < 0$|No real solutions, both are complex.|

# %% [markdown]
# 1. A git repository contains all of a project's files and changes.
# 2. Git keeps tracks of changes in the files in our repository.
# 3. A commit is a save state for the files in a repository.
# 4. A push is uploading the latest commit of a repository from Github Desktop to github.com.
# 5. A pull is updating the repository on Github Desktop with the latest changes to that repository on github.com.
# 6. Github is on the internet while Github Desktop is local.

# %% [markdown]
# ##

# %% [markdown]
# $$
# \mu = \dfrac{1}{n} \sum_{i=1}^{n}x_{i}
# $$
#
# $$
# \sigma = \sqrt{\dfrac{1}{n}\sum_{i=1}^{n}(x_{i}-\mu)^2}
# $$
#
# $$
# r=\dfrac{\sum_{i=1}^{n}(x_{i}-\mu_{X})(y_{i}-\mu_{Y})}{\sqrt{\sum_{i-1}^{n}(x_{i}-\mu_{X})^2\sum_{i=1}^{n}(y_{i}-\mu_{Y})^2}}
# $$

# %% [markdown]
# # Using Jupyter(Good)

# %%
# !cd
# Out:
# C:\Users\caden\Documents\GitHub\learning-portfolio-2024-aug-ebdb3\1.1_using_jupyter

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 6CD0-C1B4
#
#  Directory of C:\Users\caden\Documents\GitHub\learning-portfolio-2024-aug-ebdb3\1.1_using_jupyter
#
# 14/08/2024  05:03 pm    <DIR>          .
# 13/08/2024  02:47 pm    <DIR>          ..
# 14/08/2024  04:25 pm    <DIR>          .ipynb_checkpoints
# 13/08/2024  08:49 am             2,518 using_jupyter_(good).ipynb
# 13/08/2024  08:49 am             2,947 using_jupyter_(need).ipynb
# 14/08/2024  05:03 pm             6,205 using_jupyter_need.ipynb
#                3 File(s)         11,670 bytes
#                3 Dir(s)  292,123,815,936 bytes free

# %%
# %timeit x=10

# %%
!%timeit x=10

# %%
# !cd
# Out:
# C:\Users\caden\Documents\GitHub\learning-portfolio-2024-aug-ebdb3\1.1_using_jupyter

# %%
# %timeit x=10
# Out:
# 46.3 ns ± 1.07 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit 
x=10
y=10
z=10
# Out:
# 77.7 ns ± 1.69 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# KeyboardInterrupt:

# %%
print= 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(squares = [i**2 for i in range(10)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(squares = [i**2 for i in range(10)])
#
# TypeError: 'squares' is an invalid keyword argument for print()

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
x= 7
# Out:
# 46.2 ns ± 2.72 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
x = 6
# Out:
# 49.1 ns ± 0.913 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %%timeit
x = 6
y = 7
# Out:
# 59 ns ± 1.88 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
print(:3)
# Out:
#   Cell In[2], line 1
#     print(:3)
#           ^
# SyntaxError: invalid syntax

# %%
print(':3')
# Out:
# :3

# %%
print('Hello World')
print('Hello World again')
# Out:
# Hello World
# Hello World again

# %%
print('me when im silly')
#i am not actually silly
# Out:
# me when im silly

# %%
name = eeby
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name = eeby
#
# NameError: name 'eeby' is not defined

# %%
name = 'eeby'

# %%
name == 'eeby'
# Out:
# True

# %%
if name == 'eeby':
    print ('hey girl')
else:
    print('hello world!')
# Out:
# hey girl

# %% [markdown]
# [](https://cdn.discordapp.com/attachments/689037401959563490/1273212045969592390/Screenshot_2023-03-24_235516.png?ex=66be735e&is=66bd21de&hm=af0609aae0d30be525988850de20a75903a584016223f55484f7aa32e4c936af&)
